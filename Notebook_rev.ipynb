# %% [markdown]
# # Proyek Analisis Data: [BIKE-SHARING-DATASET]
# - **Nama:** Hilal Fahri Husen
# - **Email:** Hilalfahri11@gmail.com
# - **ID Dicoding:** hilal_fahri_husen

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana pengaruh kondisi musim terhadap angka peminjaman sepeda?
# - Bagaimana pengaruh kondisi cuaca terhadap angka peminjaman sepeda?
# - Berapa perbandingan peminjaman sepeda / hari pada saat hari kerja dan hari libur? (Analisis Lanjutan)
# - Kapan peek hours peminjaman sepeda saat musim peminjaman sepeda tertinggi? (Analisis Lanjutan)

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
#Mendapatkan Data
df_hour = pd.read_csv('/content/hour.csv')

# %% [markdown]
# Data bike rental (hours)
#
# [link text](https://drive.google.com/file/d/1PiHT3KrXvrb91ji3yqpgccB52GZGDgLp/view?usp=drive_link)
#
# Data bike rental (hour)
#
# [link text](https://drive.google.com/file/d/1H5PolbmaYmrTEkqMIWMy2KkPxu_3-s93/view?usp=drive_link)

# %% [markdown]
# **Insight:**
# - Mendapatkan data dapat diperoleh dengan mencari data raw dari Kaggle ataupun sumber lain. Selain itu data juga bisa didapatkan dari pengambilan secara langsung dilapangan

# %% [markdown]
# ### Assessing Data

# %%
#Akses Data
df_hour
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# 1               0           1  0.22  0.2727  0.80     0.0000       8
# 2               0           1  0.22  0.2727  0.80     0.0000       5
# 3               0           1  0.24  0.2879  0.75     0.0000       3
# 4               0           1  0.24  0.2879  0.75     0.0000       0
# ...           ...         ...   ...     ...   ...        ...     ...
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 0              13   16
# 1              32   40
# 2              27   32
# 3              10   13
# 4               1    1
# ...           ...  ...
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49
#
# [17379 rows x 17 columns]

# %% [markdown]
# **Insight:**
# - Melakukan akses data dengan method .head . Hal ini digunakan untuk mengetahui feature-feature yang terdapat pada data frame

# %%
#Pengecekan Duplicate Value

cek_null = df_hour.isnull().sum()
cek_NA = df_hour.isna().sum()
cek_duplicated = df_hour.duplicated().sum()

print(cek_NA)
print('''

''')
print(cek_null)
print('''

''')
print(cek_duplicated)
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64
#
#
#
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64
#
#
#
# 0

# %% [markdown]
# **Insight:**
# - Pada tahap assesing data kita dapat coba mengecek kesalahan nilai pada data kita. Kesalahan nilai dapat berupa data duplikat dan data yang kosong. Pengecekan dapat dibantu dengan method isnull() untuk pengecekan nilai null, isna() untuk pengecekan nilai NA, duplicate() unutk mengecek duplicate, dan sum() untuk menjumlahkan berapa banyak data yang mengalami kesalahan.
#
# - Pada pengecekan diatas didapatkan bahwa tidak terdapat nilai duplicat, null, dan NA

# %% [markdown]
# ### Cleaning Data

# %%
#Penanganan Outliers

Q1 = (df_hour['cnt']).quantile(0.25)
Q3 = (df_hour['cnt']).quantile(0.75)
IQR = Q3 - Q1

maximum = Q3 + (1.5*IQR)
minimum = Q1 - (1.5*IQR)

kondisi_lower_than = df_hour['cnt'] < minimum
kondisi_more_than = df_hour['cnt'] > maximum

cek_outlier1 = kondisi_lower_than.sum()
cek_outlier2 = kondisi_more_than.sum()

print(cek_outlier1)
print(cek_outlier2)
# Out:
# 0
# 505

# %% [markdown]
# **Insight:**
# - Cleaning Data salah satunya berisi terkait menghapus menghapus outlier pada data. Hal ini dibantu dengan beberapa perhitungan statistic terhadap data, antara lain perhitungan quartile lalu menentukan kondisi maximal dan minimal pada data. Data yang dipakai untuk perhitungan ini adalah data dari cnt yang berisi total perentalan sepeda.
# - Proses diatas merupakan pengecekan nilai yang termasuk outlier

# %%
#Penghapusan nilai outlier

df_hour.drop(df_hour[kondisi_lower_than].index, inplace=True)
df_hour.drop(df_hour[kondisi_more_than].index, inplace=True)

df_hour
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# 1               0           1  0.22  0.2727  0.80     0.0000       8
# 2               0           1  0.22  0.2727  0.80     0.0000       5
# 3               0           1  0.24  0.2879  0.75     0.0000       3
# 4               0           1  0.24  0.2879  0.75     0.0000       0
# ...           ...         ...   ...     ...   ...        ...     ...
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 0              13   16
# 1              32   40
# 2              27   32
# 3              10   13
# 4               1    1
# ...           ...  ...
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49
#
# [16874 rows x 17 columns]

# %% [markdown]
# **Insight:**
# - Proses diatas adalah proses untuk penghapusan nilai yang tergolong outlier d

# %%
weather_mapping = {
    1: "Clear, Few clouds",
    2: "Mist + Cloudy, Mist",
    3: "Light Snow, Light Rain clouds",
    4: "Heavy Rain"
}

# Menambahkan kolom baru 'weather_desc' berdasarkan referensi kolom 'weathersit'
df_hour['weather_desc'] = df_hour['weathersit'].map(weather_mapping)

season_mapping = {
    1: "spring",
    2: "summer",
    3: "fall",
    4: "winter"
}

# Menambahkan kolom baru 'season_desc' berdasarkan referensi kolom 'season'
df_hour['season_desc'] = df_hour['season'].map(season_mapping)

Holiday_mapping = {
    0: "Working hour",
    1: "Holiday"
}

# Menambahkan kolom baru 'hour_desc' berdasarkan referensi kolom 'holihour'
df_hour['day_desc'] = df_hour['holiday'].map(Holiday_mapping)


# Menampilkan hasil
print(df_hour)
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# 1               0           1  0.22  0.2727  0.80     0.0000       8
# 2               0           1  0.22  0.2727  0.80     0.0000       5
# 3               0           1  0.24  0.2879  0.75     0.0000       3
# 4               0           1  0.24  0.2879  0.75     0.0000       0
# ...           ...         ...   ...     ...   ...        ...     ...
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt         weather_desc season_desc      day_desc
# 0              13   16    Clear, Few clouds      spring  Working hour
# 1              32   40    Clear, Few clouds      spring  Working hour
# 2              27   32    Clear, Few clouds      spring  Working hour
# 3              10   13    Clear, Few clouds      spring  Working hour
# 4               1    1    Clear, Few clouds      spring  Working hour
# ...           ...  ...                  ...         ...           ...
# 17374         108  119  Mist + Cloudy, Mist      spring  Working hour
# 17375          81   89  Mist + Cloudy, Mist      spring  Working hour
# 17376          83   90    Clear, Few clouds      spring  Working hour
# 17377          48   61    Clear, Few clouds      spring  Working hour
# 17378          37   49    Clear, Few clouds      spring  Working hour
#
# [16874 rows x 20 columns]

# %% [markdown]
# **Insight:**
#
# - Pada data ini saya ingin menambahkan kolom terkait nilai sebenarnya dari angka pada kolom season, weathersit, holiday sesuai yang tertera pada readme. Hal ini merupakann bagian cleaning data sehingga data akan siap digunakan untuk analisis

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
df_hour.describe()
# Out:
#             instant        season            yr          mnth            hr  \
# count  16874.000000  16874.000000  16874.000000  16874.000000  16874.000000
# mean    8542.168899      2.490399      0.487733      6.513275     11.458101
# std     5007.766040      1.111966      0.499864      3.462438      6.962144
# min        1.000000      1.000000      0.000000      1.000000      0.000000
# 25%     4219.250000      1.000000      0.000000      4.000000      5.000000
# 50%     8438.500000      2.000000      0.000000      7.000000     11.000000
# 75%    12832.750000      3.000000      1.000000     10.000000     18.000000
# max    17379.000000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  16874.000000  16874.000000  16874.000000  16874.000000  16874.000000
# mean       0.029513      2.997748      0.678618      1.430663      0.492650
# std        0.169244      2.013054      0.467021      0.642689      0.192455
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.640000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  16874.000000  16874.000000  16874.000000  16874.000000  16874.000000
# mean       0.471970      0.630412      0.189619     33.418632    139.291514
# std        0.171878      0.192600      0.122460     45.896591    126.052802
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     32.000000
# 50%        0.484800      0.630000      0.179100     15.000000    111.000000
# 75%        0.621200      0.790000      0.253700     45.000000    208.000000
# max        1.000000      1.000000      0.850700    354.000000    629.000000
#
#                 cnt
# count  16874.000000
# mean     172.710146
# std      155.020918
# min        1.000000
# 25%       38.000000
# 50%      135.000000
# 75%      265.750000
# max      642.000000

# %% [markdown]
# **Insight:**
#
# - .describe() digunakan untuk mengetahu beberapa parameter statistik pada data yang kita miliki. Pada metode describe() kita dapat mengetahui jumlah data, rata-rata, standar deviasi, quartil 1, quartil 2, quartil 3, nilai max, dan nilai min. Semua nilai ini sangat bermanfaat untuk pemrosesan statistik.

# %%
#from google.colab import files
#df_rentals_byseason.to_csv('Rental_by_Season.csv', index=False)
#files.download('Rental_by_Season.csv')

df_rentals_byseason = df_hour.groupby(by="season_desc", as_index=False
).agg(
    sum_hour=("instant", "nunique"),   # Jumlah hari unik
    total_rentals=("cnt", "sum"),     # Total rental sepeda
    rentals_per_hours =("cnt", "mean")      # Rata-rata rental sepeda
).sort_values(by="total_rentals", ascending=False)


print(df_rentals_byseason)
# Out:
#   season_desc  sum_hour  total_rentals  rentals_per_hours
# 0        fall      4298         909146         211.527687
# 2      summer      4253         805771         189.459440
# 3      winter      4100         741576         180.872195
# 1      spring      4223         457818         108.410609

# %% [markdown]
# **Insight:**
#
# - Pada data ini saya ingin membuat suatu kolom dengan data dari jumlah perentalan pada setiap musim yang ada. Untuk mengetahui musim kesukaan masyarakat dalam perentalan sepeda

# %%
df_rentals_byweather= df_hour.groupby(by="weather_desc", as_index=False
).agg(
    sum_hour=("instant", "nunique"),   # Jumlah hari unik
    total_rentals=("cnt", "sum"),     # Total rental sepeda
    rentals_per_hours =("cnt", "mean")      # Rata-rata rental sepeda
).sort_values(by="total_rentals", ascending=False)


print(df_rentals_byweather)
# Out:
#                     weather_desc  sum_hour  total_rentals  rentals_per_hours
# 0              Clear, Few clouds     11020        2042163         185.314247
# 3            Mist + Cloudy, Mist      4444         722712         162.626463
# 2  Light Snow, Light Rain clouds      1407         149213         106.050462
# 1                     Heavy Rain         3            223          74.333333

# %% [markdown]
# **Insight:**
#
# - Pada data ini saya ingin membuat suatu kolom dengan data dari jumlah perentalan pada setiap cuaca yang ada. Untuk mengetahui cuaca kesukaan masyarakat dalam perentalan sepeda

# %%
df_rentals_byhourdesc= df_hour.groupby(by="day_desc", as_index=False
).agg(
    sum_hour=("instant", "nunique"),   # Jumlah hari unik
    total_rentals=("cnt", "sum"),     # Total rental sepeda
    rentals_per_hours =("cnt", "mean")      # Rata-rata rental sepeda
).sort_values(by="total_rentals", ascending=False)


print(df_rentals_byhourdesc)
# Out:
#        day_desc  sum_hour  total_rentals  rentals_per_hours
# 1  Working hour     16376        2837264         173.257450
# 0       Holiday       498          77047         154.712851

# %% [markdown]
# **Insight:**
#
# - Pada data ini saya ingin membuat suatu kolom dengan data dari jumlah perentalan pada Hari libur dan tidak. Hal ini dilakukan untuk mengetahui jumlah rental perhours dalam hari libur atau kerja tersebut

# %%
df_fall = df_hour[df_hour["season"] == 3]
df_peek_hours = df_fall.groupby(by="hr", as_index=False
).agg(
      peek_hours_rental = ("cnt","mean")
).sort_values(by="hr",ascending = True)


df_peek_hours["peek_hours_rental"] = df_peek_hours["peek_hours_rental"].round()

print(df_peek_hours)
# Out:
#     hr  peek_hours_rental
# 0    0               74.0
# 1    1               44.0
# 2    2               31.0
# 3    3               16.0
# 4    4                8.0
# 5    5               26.0
# 6    6              101.0
# 7    7              277.0
# 8    8              310.0
# 9    9              255.0
# 10  10              215.0
# 11  11              252.0
# 12  12              287.0
# 13  13              283.0
# 14  14              274.0
# 15  15              282.0
# 16  16              364.0
# 17  17              451.0
# 18  18              444.0
# 19  19              405.0
# 20  20              313.0
# 21  21              241.0
# 22  22              184.0
# 23  23              123.0

# %% [markdown]
# **Insight:**
#
# - Pada data ini saya ingin membuat suatu kolom dengan data dari jumlah perentalan pada musim yang memiliki jumlah perentalan tertinggi, yaitu musim fall. Hal ini dilakukan karena ada kemungkinan kita bisa menganalisis peretanalan tertinggi pada suatu waktu ada dimana.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
# Filter data
df_pertanyaan1 = df_rentals_byseason[['season_desc', 'total_rentals']]

# Set palet warna
colors = sns.color_palette("pastel")

# Plot
plt.figure(figsize=(10, 5))
ax = sns.barplot(df_pertanyaan1,
    y="total_rentals",
    x="season_desc",
    palette=colors
)

for container in ax.containers:
    ax.bar_label(container, fontsize=10)

# Tambahkan judul dan label sumbu
plt.title("Total Rental by Season", loc="center", fontsize=15)
plt.xlabel("Season", fontsize=12)
plt.ylabel("Total Rentals", fontsize=12)
plt.xticks(rotation=0)
plt.tight_layout()

# Tampilkan plot
plt.show()
# Out:
# <ipython-input-15-4abb0e30e09e>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(df_pertanyaan1,
# <ipython-input-15-4abb0e30e09e>:9: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   ax = sns.barplot(df_pertanyaan1,

# %% [markdown]
# **Insight:**
# - Pada grafik diatas dapat dikatakan bahwa jumlah perentalan tertinggi terdapat pada musim gugur dan paling sedikit pada musim semi.
#
# - Sehingga apabila pada grafik ini perental dapat melakukan alokasi unit perentalan atau pembelian unit baru pada musim gugur dibandingkan musim lain.

# %% [markdown]
# ### Pertanyaan 2:

# %%
# Filter data
df_pertanyaan2 = df_rentals_byweather[['weather_desc', 'total_rentals']]

# Set palet warna
colors = sns.color_palette("pastel")

# Plot
plt.figure(figsize=(10, 5))
ax = sns.barplot(
    y="total_rentals",
    x="weather_desc",
    data=df_pertanyaan2.sort_values(by="weather_desc", ascending=False),
    palette=colors
)

for container in ax.containers:
    ax.bar_label(container, fontsize=10)

# Tambahkan judul dan label sumbu
plt.title("Total Rental by Weather", loc="center", fontsize=15)
plt.xlabel("Weather", fontsize=12)
plt.ylabel("Total Rentals", fontsize=12)
plt.xticks(rotation=0)
plt.tight_layout()

# Tampilkan plot
plt.show()
# Out:
# <ipython-input-16-8599f79a2d1a>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
# <ipython-input-16-8599f79a2d1a>:9: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   ax = sns.barplot(

# %% [markdown]
# **Insight:**
# - Jumlah perentalan tertinggi berdasarkan cuaca tertinggi terdapat pada cuaca clear, Few Clouds dan terendah pada heavy rain. Hal ini sangat beralasan sekali karena saat cuaca cerah kita lebih ingin merental sepeda daripada saat cuaca hujan deras.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
# Filter data
df_pertanyaan3 = df_rentals_byhourdesc[['day_desc', 'rentals_per_hours']]

# Set palet warna
colors = sns.color_palette("pastel")

# Plot
plt.figure(figsize=(10, 5))
ax = sns.barplot(
    y="rentals_per_hours",
    x="day_desc",
    data=df_pertanyaan3.sort_values(by="day_desc", ascending=False),
    palette=colors
)

for container in ax.containers:
    ax.bar_label(container, fontsize=10)

# Tambahkan judul dan label sumbu
plt.title("Rental/hour by Day_desc", loc="center", fontsize=15)
plt.xlabel("Day_desc", fontsize=12)
plt.ylabel("Total Rentals (Rental/hour)", fontsize=12)
plt.xticks(rotation=0)
plt.tight_layout()

# Tampilkan plot
plt.show()
# Out:
# <ipython-input-17-77132509b1a7>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
# <ipython-input-17-77132509b1a7>:9: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   ax = sns.barplot(

# %% [markdown]
# **Insight:**
# - Data diatas Merupakan rental/hours pada hari kerja dan hari libur. Pada data tersebut perentalan pada hari kerja unggul sekitar 20 rental daripada saat holiday. Hal ini menandakan mungkin terdapat jumlah perentalan namun tidak terlalu signifikan

# %%
# Filter data
df_pertanyaan3 = df_peek_hours[['peek_hours_rental', 'hr']]

# Set palet warna
colors = sns.color_palette("pastel")

# Plot
plt.figure(figsize=(10, 5))
ax = sns.barplot(
    y="peek_hours_rental",
    x="hr",
    data=df_pertanyaan3.sort_values(by="hr", ascending=False),
    palette=colors
)

for container in ax.containers:
    ax.bar_label(container, fontsize=10)
# Tambahkan judul dan label sumbu
plt.title("Rental/hour by hour", loc="center", fontsize=15)
plt.xlabel("hour", fontsize=12)
plt.ylabel("Total Rentals (Rental/hour)", fontsize=12)
plt.xticks(rotation=0)
plt.tight_layout()

# Tampilkan plot
plt.show()
# Out:
# <ipython-input-18-6d889d1816ab>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
# <ipython-input-18-6d889d1816ab>:9: UserWarning:
# The palette list has fewer values (10) than needed (24) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.barplot(

# %% [markdown]
# **Insight:**
# - Data diatas adalah data jumlah perentalan pada jam-jam tertentu pada musim gugur. Dapat diilihat bahwa rental/hours paling tinggi terdapat pada jam 5 - 7 sore. Hal ini mungkin berkaitan dengan jam pulang kerja dari daerah tersebut.

# %% [markdown]
# ## CONCLUTION

# %% [markdown]
# - **Conclution pertanyaan 1**
# - Jumlah perentalan sepeda tertinggi terdapat pada musim gugur dan terendah pada musim semi. Pada musim gugur terdapat 909146 perentalan sepeda, Pada musim panas terdapat 805771 perentalan sepeda, Pada musim dingin terdapat 741576 perentalan sepeda, dan pada musim semi terdapat total 457818 perentalan sepeda. Dari hal ini dapat disarankan untuk menaikan jumlah unit sepeda pada musim gugur karena pada musim tersebut jumlah perentalan terdapat pada puncaknya.
#
# - **Conclution pertanyaan 2**
# - Jumlah perentalan sepeda tertinggi terdapat saat cuaca cerah dan terendah pada saat cuaca dengan curah hujan tinggi. Pada saat cuaca cerah (clear,few clouds) terdapat total perentalan sepeda 2042160, pada saat cuaca berkabut (mist+cloud) terdapat 722712 perentalan, pada saat cuaca light snow terdapat 149213 perentalan sepeda, dan pada saat curah hujan/ salju tinggi hanya terdapat total 223 perentalan sepeda. Pada data tersebut kita dapat mengombinasikan dengan ramalan cuaca dihari tersebut untuk memprediksi jam puncak perentalan pada hari tertentu.
#
# - **Conclution optional 1**
# - Rental/Hour pada hari kerja dan hari libur hanya berbeda sekitar 20 rental tiap jamnya. Hal ini membuat kita tahu bahwa tidak ada perbedaan signifikan dari hari libur dan hari biasa. Sehingga didapatka insight bahwa alangkah baiknya apabila tetap menjaga peforma cabang meskipun saat hari libur.
#
# - **Conclution optional 2**
# - Rental/Hour puncak terdapat pada jam 5 dilihat dari data musim gugur. Hal ini dapat dijadikan masukan untuk melakukan / memperketat pelayanan pada jam tersebut dan menaikan jumlah unit perentalan pada jam tersebut.
